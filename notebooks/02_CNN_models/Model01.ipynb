# %%
import h5py 
import tensorflow as tf
import tensorflow.keras.layers as tfl
# Out:
# 2026-01-27 15:17:21.739391: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-27 15:17:21.810125: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-27 15:17:22.302329: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-27 15:17:24.808189: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with h5py.File("../../EIDSeg_Dataset/cache/eidseg_64x64_binary_any.h5", "r") as f:
    X_train_org = f["X_train"][:]
    Y_train_org = f["Y_train"][:]
    X_test_org  = f["X_test"][:]
    Y_test_org  = f["Y_test"][:]

m_train = X_train_org.shape[0]
m_test = X_test_org.shape[0]
num_px =X_train_org.shape[1]

print ("Number of training examples: m_train = " + str(m_train))
print ("Number of testing examples: m_test = " + str(m_test))
print ("Height/Width of each image: num_px = " + str(num_px))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_set_x shape: " + str(X_train_org.shape))
print ("train_set_y shape: " + str(Y_train_org.shape))
print ("test_set_x shape: " + str(X_test_org.shape))
print ("test_set_y shape: " + str(Y_test_org.shape))
# Out:
# Number of training examples: m_train = 2612
# Number of testing examples: m_test = 327
# Height/Width of each image: num_px = 64
# Each image is of size: (64, 64, 3)
# train_set_x shape: (2612, 64, 64, 3)
# train_set_y shape: (1, 2612)
# test_set_x shape: (327, 64, 64, 3)
# test_set_y shape: (1, 327)

# %%
def building_damage_model():

    model = tf.keras.Sequential([
        # Input + first convolution block
        tf.keras.layers.Conv2D(
            filters=32,
            kernel_size=(3, 3),
            strides=1,
            padding='same',
            activation='relu',
            input_shape=(64, 64, 3)
        ),
        tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2),

        # Second convolution block
        tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=(3, 3),
            strides=1,
            padding='same',
            activation='relu'
        ),
        tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2),

        # Classifier
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %%
model = building_damage_model()

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = building_damage_model()
#       3 model.compile(
#       4     optimizer='adam',
#       5     loss='binary_crossentropy',
#       6     metrics=['accuracy']
#       7 )
#
# Cell In[6], line 3, in building_damage_model()
#       1 def building_damage_model():
# ----> 3     model = tf.keras.Sequential([
#       4         # Input + first convolution block
#       5         tf.keras.layers.Conv2D(
#       6             filters=32,
#       7             kernel_size=(3, 3),
#       8             strides=1,
#       9             padding='same',
#      10             activation='relu',
#      11             input_shape=(64, 64, 3)
#      12         ),
#      13         tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2),
#      14
#      15         # Second convolution block
#      16         tf.keras.layers.Conv2D(
#      17             filters=64,
#      18             kernel_size=(3, 3),
#      19             strides=1,
#      20             padding='same',
#      21             activation='relu'
#      22         ),
#      23         tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2),
#      24
#      25         # Classifier
#      26         tf.keras.layers.Flatten(),
#      27         tf.keras.layers.Dense(64, activation='relu'),
#      28         tf.keras.layers.Dense(1, activation='sigmoid')
#      29     ])
#      31     return model
#
# NameError: name 'tf' is not defined

# %%
Y_train = Y_train_org.reshape(-1)
Y_test  = Y_test_org.reshape(-1)

# %%
X_train = X_train_org / 255.0
X_test  = X_test_org / 255.0
